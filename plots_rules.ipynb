# %%
import train as t
import numpy as np
import matplotlib.pyplot as plt

# Please, to run the experiment run create_dataset_A.m
# The eniter Notebook can take quite long to run completely, please consider to reduce the max iter paramenter and/or the block sizes
# To reduce the max_iter paramenter is enough to decrease the numbers in the respective variables
# To reduce the block_size tested is enouhg to reduce the lenght of the block_size list in the dictionaries EXP_GROUPS

write_exp = True   # if true compute_for_plots save the results on a txt file in Figure/
write_fig = True   # if true comparative_plots save the plots on a pdf file in Figure/ 
debug = True       # if true print some infos about the running algorithm

# %%
# FIG4a and 8 and 10

EXP_GROUPS = {}
EXP_GROUPS['fig4a_and_8_and_10'] = {'partition':["VB", "Sort"],
                    'selection':['Random', 'Cyclic', 'Lipschitz', 'GS', 'GSDHb', 'GSL', 'Perm'],
                    'update':['Lb'],
                    'block_size': [5, 50, 100],
                    'l1':0, 'l2':0}

# %%
# max_iter_array[partititon][block_size]

max_iter = [[20,20,20],[20,20,20]]
if write_exp: t.compute_for_plots("ls", EXP_GROUPS, max_iter, write_exp, debug)
# Out:
# fig4a_and_8_and_10 VB Random Lb
# Start Caratheodory
# {'dis2opt': 387175.0100838974, 'iteration': 0, 'selected': array([], dtype=float64), 'total_CA_iter': 0, 'time': 0.32370775600000457}
# /Users/fcosentino/OneDrive/__PhD Oxf ATI - CS/_Courses/_Recombination/_CA_BlockCoordDesc/Code_makefast_merge official ONLY CA/recombination.py:889: RuntimeWarning: invalid value encountered in true_divide
#   alpha = mu/Phi[:,0]
# {'dis2opt': 383354.29086619255, 'iteration': 1, 'selected': array([ 90, 254, 283, 445, 461]), 'total_CA_iter': 1.000495, 'time': 0.9046862030000042}
# /Users/fcosentino/OneDrive/__PhD Oxf ATI - CS/_Courses/_Recombination/_CA_BlockCoordDesc/Code_makefast_merge official ONLY CA/recombination.py:1017: RuntimeWarning: divide by zero encountered in true_divide
#   A_new = A_old - prod_2/c
# ...

# %%
max_iter = [[20,20,20],[20,20,20]]
t.comparative_plots("ls", EXP_GROUPS, max_iter, write_fig)
# Out:
# fig4a_and_8_and_10 VB Random Lb
# fig4a_and_8_and_10 VB Cyclic Lb
# fig4a_and_8_and_10 VB Lipschitz Lb
# fig4a_and_8_and_10 VB GS Lb
# fig4a_and_8_and_10 VB GSDHb Lb
# fig4a_and_8_and_10 VB GSL Lb
# fig4a_and_8_and_10 VB Perm Lb
# fig4a_and_8_and_10 VB Random Lb
# fig4a_and_8_and_10 VB Cyclic Lb
# fig4a_and_8_and_10 VB Lipschitz Lb
# fig4a_and_8_and_10 VB GS Lb
# fig4a_and_8_and_10 VB GSDHb Lb
# fig4a_and_8_and_10 VB GSL Lb
# fig4a_and_8_and_10 VB Perm Lb
# fig4a_and_8_and_10 VB Random Lb
# fig4a_and_8_and_10 VB Cyclic Lb
# fig4a_and_8_and_10 VB Lipschitz Lb
# fig4a_and_8_and_10 VB GS Lb
# fig4a_and_8_and_10 VB GSDHb Lb
# fig4a_and_8_and_10 VB GSL Lb
# fig4a_and_8_and_10 VB Perm Lb
# fig4a_and_8_and_10 Sort Random Lb
# fig4a_and_8_and_10 Sort Cyclic Lb
# fig4a_and_8_and_10 Sort Lipschitz Lb
# fig4a_and_8_and_10 Sort GS Lb
# fig4a_and_8_and_10 Sort GSDHb Lb
# fig4a_and_8_and_10 Sort GSL Lb
# fig4a_and_8_and_10 Sort Perm Lb
# fig4a_and_8_and_10 Sort Random Lb
# ...

# %%
# FIG5a

EXP_GROUPS = {}
EXP_GROUPS['fig5a'] = {'partition':["VB", "Sort"],
                    'selection':['GSQ', 'GS', 'GSL', 'GSD', 'IHT', 'GSDHb'],
                    'update':['Hb'],
                    'block_size':[5], 
                    'l1':0, 'l2':0}

# %%
max_iter = [[20],[20]]
if write_exp: t.compute_for_plots("ls", EXP_GROUPS, max_iter, write_exp, debug)
# Out:
# fig5a VB GSQ Hb
# Start Caratheodory
# {'dis2opt': 387175.0100838974, 'iteration': 0, 'selected': array([], dtype=float64), 'total_CA_iter': 0, 'time': 0.36782356399999117}
# fig5a VB GS Hb
# Start Caratheodory
# {'dis2opt': 387175.0100838974, 'iteration': 0, 'selected': array([], dtype=float64), 'total_CA_iter': 0, 'time': 0.37534153100023104}
# /Users/fcosentino/OneDrive/__PhD Oxf ATI - CS/_Courses/_Recombination/_CA_BlockCoordDesc/Code_makefast_merge official ONLY CA/recombination.py:889: RuntimeWarning: invalid value encountered in true_divide
#   alpha = mu/Phi[:,0]
# {'dis2opt': 125010.53865168511, 'iteration': 1, 'selected': array([124, 172, 191, 214, 323]), 'total_CA_iter': 1.0, 'time': 4.181503488000089}
# {'dis2opt': 49219.01573814207, 'iteration': 2, 'selected': array([157, 193, 291, 391, 432]), 'total_CA_iter': 2.0, 'time': 8.051875719000236}
# ...

# %%
max_iter = [[20],[20]]
t.comparative_plots("ls", EXP_GROUPS, max_iter, write_fig)
# Out:
# fig5a VB GSQ Hb
# fig5a VB GS Hb
# fig5a VB GSL Hb
# fig5a VB GSD Hb
# fig5a VB IHT Hb
# fig5a VB GSDHb Hb
# fig5a Sort GSQ Hb
# fig5a Sort GS Hb
# fig5a Sort GSL Hb
# fig5a Sort GSD Hb
# fig5a Sort IHT Hb
# fig5a Sort GSDHb Hb

# %%
# FIG9 and 10

EXP_GROUPS = {} 
EXP_GROUPS['fig9_and_10'] = {'partition':["Order"],
                    'selection':["GS", 'GSL', 'Lipschitz', 'Random', 'Cyclic'],
                    'update':['Lb'],
                    'block_size':[5, 50, 100],
                    'l1':0, 'l2':0}

# %%
max_iter = [[20,20,20]]
if write_exp: t.compute_for_plots("ls", EXP_GROUPS, max_iter, write_exp, debug)
# Out:
# fig9_and_10 Order GS Lb
# Start Caratheodory
# {'dis2opt': 387175.0100838974, 'iteration': 0, 'selected': array([], dtype=float64), 'total_CA_iter': 0, 'time': 0.3026862850001635}
# /Users/fcosentino/OneDrive/__PhD Oxf ATI - CS/_Courses/_Recombination/_CA_BlockCoordDesc/Code_makefast_merge official ONLY CA/recombination.py:1017: RuntimeWarning: divide by zero encountered in true_divide
#   A_new = A_old - prod_2/c
# /Users/fcosentino/OneDrive/__PhD Oxf ATI - CS/_Courses/_Recombination/_CA_BlockCoordDesc/Code_makefast_merge official ONLY CA/recombination.py:355: RuntimeWarning: invalid value encountered in matmul
#   test_inv = np.matmul(A,np.transpose(X[idx,:]))
# /Users/fcosentino/OneDrive/__PhD Oxf ATI - CS/_Courses/_Recombination/_CA_BlockCoordDesc/Code_makefast_merge official ONLY CA/recombination.py:889: RuntimeWarning: invalid value encountered in true_divide
#   alpha = mu/Phi[:,0]
# ...

# %%
max_iter = [[20,20,20]]
t.comparative_plots("ls", EXP_GROUPS, max_iter, write_fig)
# Out:
# fig9_and_10 Order GS Lb
# fig9_and_10 Order GSL Lb
# fig9_and_10 Order Lipschitz Lb
# fig9_and_10 Order Random Lb
# fig9_and_10 Order Cyclic Lb
# fig9_and_10 Order GS Lb
# fig9_and_10 Order GSL Lb
# fig9_and_10 Order Lipschitz Lb
# fig9_and_10 Order Random Lb
# fig9_and_10 Order Cyclic Lb
# fig9_and_10 Order GS Lb
# fig9_and_10 Order GSL Lb
# fig9_and_10 Order Lipschitz Lb
# fig9_and_10 Order Random Lb
# fig9_and_10 Order Cyclic Lb

# %%
# FIG10

EXP_GROUPS = {} 
EXP_GROUPS['fig10'] = {'partition':['Avg'],
                    'selection':['GS', 'GSD', 'GSL'],
                    'update':['Lb'],
                    'block_size':[5, 20, 50],
                    'l1':0, 'l2':0}

# %%
max_iter = [[20,20,20]]
if write_exp: t.compute_for_plots("ls", EXP_GROUPS, max_iter, write_exp, debug)
# Out:
# fig10 Avg GS Lb
# Start Caratheodory
# {'dis2opt': 387175.0100838974, 'iteration': 0, 'selected': array([], dtype=float64), 'total_CA_iter': 0, 'time': 0.39874325300024793}
# /Users/fcosentino/OneDrive/__PhD Oxf ATI - CS/_Courses/_Recombination/_CA_BlockCoordDesc/Code_makefast_merge official ONLY CA/recombination.py:889: RuntimeWarning: invalid value encountered in true_divide
#   alpha = mu/Phi[:,0]
# /Users/fcosentino/OneDrive/__PhD Oxf ATI - CS/_Courses/_Recombination/_CA_BlockCoordDesc/Code_makefast_merge official ONLY CA/recombination.py:889: RuntimeWarning: divide by zero encountered in true_divide
#   alpha = mu/Phi[:,0]
# {'dis2opt': 305937.85254825535, 'iteration': 1, 'selected': array([ 35, 235, 130, 493, 214]), 'total_CA_iter': 1.000495, 'time': 4.599058585000421}
# /Users/fcosentino/OneDrive/__PhD Oxf ATI - CS/_Courses/_Recombination/_CA_BlockCoordDesc/Code_makefast_merge official ONLY CA/recombination.py:1017: RuntimeWarning: divide by zero encountered in true_divide
# ...

# %%
max_iter = [[20,20,20]]
t.comparative_plots("ls", EXP_GROUPS, max_iter, write_fig)
# Out:
# fig10 Avg GS Lb
# fig10 Avg GSD Lb
# fig10 Avg GSL Lb
# fig10 Avg GS Lb
# fig10 Avg GSD Lb
# fig10 Avg GSL Lb
# fig10 Avg GS Lb
# fig10 Avg GSD Lb
# fig10 Avg GSL Lb

# %%
# FIG11

EXP_GROUPS = {} 
EXP_GROUPS['fig11'] = {'partition':["Sort", "VB"],
                    'selection':["GSQ", "GS", "GSL", "GSD", "IHT"],
                    'update':['Hb'],
                    'block_size':[5, 50, 100],
                    'l1':0, 'l2':0}

# %%
max_iter = [[20,20,20],[20,20,20]]
if write_exp: t.compute_for_plots("ls", EXP_GROUPS, max_iter, write_exp, debug)
# Out:
# fig11 Sort GSQ Hb
# Start Caratheodory
# {'dis2opt': 387175.0100838974, 'iteration': 0, 'selected': array([], dtype=float64), 'total_CA_iter': 0, 'time': 0.238643695999599}
# /Users/fcosentino/OneDrive/__PhD Oxf ATI - CS/_Courses/_Recombination/_CA_BlockCoordDesc/Code_makefast_merge official ONLY CA/recombination.py:889: RuntimeWarning: invalid value encountered in true_divide
#   alpha = mu/Phi[:,0]
# {'dis2opt': 284086.55162985413, 'iteration': 1, 'selected': array([124, 469, 402, 446, 430]), 'total_CA_iter': 1.0, 'time': 6.002875541999856}
# /Users/fcosentino/OneDrive/__PhD Oxf ATI - CS/_Courses/_Recombination/_CA_BlockCoordDesc/Code_makefast_merge official ONLY CA/recombination.py:1017: RuntimeWarning: divide by zero encountered in true_divide
#   A_new = A_old - prod_2/c
# /Users/fcosentino/OneDrive/__PhD Oxf ATI - CS/_Courses/_Recombination/_CA_BlockCoordDesc/Code_makefast_merge official ONLY CA/recombination.py:355: RuntimeWarning: invalid value encountered in matmul
# ...

# %%
max_iter = [[20,20,20],[20,20,20]]
t.comparative_plots("ls", EXP_GROUPS, max_iter,  write_fig)
# Out:
# fig11 Sort GSQ Hb
# fig11 Sort GS Hb
# fig11 Sort GSL Hb
# fig11 Sort GSD Hb
# fig11 Sort IHT Hb
# fig11 Sort GSQ Hb
# fig11 Sort GS Hb
# fig11 Sort GSL Hb
# fig11 Sort GSD Hb
# fig11 Sort IHT Hb
# fig11 Sort GSQ Hb
# fig11 Sort GS Hb
# fig11 Sort GSL Hb
# fig11 Sort GSD Hb
# fig11 Sort IHT Hb
# fig11 VB GSQ Hb
# fig11 VB GS Hb
# fig11 VB GSL Hb
# fig11 VB GSD Hb
# fig11 VB IHT Hb
# fig11 VB GSQ Hb
# fig11 VB GS Hb
# fig11 VB GSL Hb
# fig11 VB GSD Hb
# fig11 VB IHT Hb
# fig11 VB GSQ Hb
# fig11 VB GS Hb
# fig11 VB GSL Hb
# fig11 VB GSD Hb
# fig11 VB IHT Hb
